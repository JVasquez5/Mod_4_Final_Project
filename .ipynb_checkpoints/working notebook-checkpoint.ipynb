# %% [markdown]
# # Final Project Submission
#
# Please fill out:
# * Student name: Thomas Hill & Jonathan Vasquez
# * Student pace: Full Time
# * Scheduled project review date/time: 07/31/2020
# * Instructor name: Fangfang Lee
# * Blog post URL:

# %% [markdown]
# # Importing Libraries / Data

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from matplotlib import pyplot as plt #Ploting charts
from glob import glob #retriving an array of files in directories

import tensorflow as tf
import cv2
from sklearn.metrics import confusion_matrix, f1_score, classification_report
np.random.seed(123)

import keras
from keras import models
from keras import layers

from keras.models import load_model, Sequential #for neural network models
from keras.layers import Dense, Dropout, Flatten, ZeroPadding2D, Conv2D, MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator #Data augmentation and preprocessing
from keras.preprocessing.image import array_to_img, img_to_array, load_img
from keras.utils import to_categorical #For One-hot Encoding
from keras.optimizers import Adam, SGD, RMSprop #For Optimizing the Neural Network
from keras.callbacks import EarlyStopping

import os

# %%
print(os.listdir("../Mod_4_Final_Project/chest_xray"))
# Out:
# ['.DS_Store', 'test', 'train', 'val']

# %%
train_dir = '../Mod_4_Final_Project/chest_xray/train'
test_dir =  '../Mod_4_Final_Project/chest_xray/test'
val_dir = '../Mod_4_Final_Project/chest_xray/val'

# %% [markdown]
# # Visualizing the Data

# %%
p_train_img = glob(train_dir+"/PNEUMONIA/*.jpeg") #Getting all images in this folder
p_train_img = np.asarray(plt.imread(p_train_img[0]))

# %%
plt.imshow(p_train_img)
print("This is an example of a patient X-ray who does not have pneumonia:")
# Out:
# This is an example of a patient X-ray who does not have pneumonia:

# %%
p_train_img.shape
# Out:
# (736, 1048)

# %%
n_train_img = glob(train_dir+"/NORMAL/*.jpeg") #Getting all images in this folder
n_train_img = np.asarray(plt.imread(n_train_img[0]))

# %%
plt.imshow(n_train_img)
print("This is an example of an X-ray of a patient diagnosed with pneumonia:")
# Out:
# This is an example of an X-ray of a patient diagnosed with pneumonia:

# %%
n_train_img.shape
# Out:
# (2234, 2359)

# %%
print("There are " +str(len(p_train_img)) +" pneumonia positive X-ray's in our data")
print("There are " +str(len(n_train_img)) +" pneumonia negative X-ray's in our data")
# Out:
# There are 736 pneumonia positive X-ray's in our data
# There are 2234 pneumonia negative X-ray's in our data
