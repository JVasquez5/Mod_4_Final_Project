# %% [markdown]
# # Final Project Submission
#
# Please fill out:
# * Student name: Thomas Hill & Jonathan Vasquez
# * Student pace: Full Time
# * Scheduled project review date/time: 07/31/2020
# * Instructor name: Fangfang Lee
# * Blog post URL:

# %%
import matplotlib.pyplot as plt
import numpy as np
import os, shutil
from keras import models
from keras import layers
from sklearn.metrics import confusion_matrix, f1_score
np.random.seed(123)
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
import cv2
import glob
import matplotlib.pyplot as plt
import random
from random import randint
from pathlib import Path
import os
print(os.listdir("../Mod_4_Final_Project/chest_xray"))
# Out:
# ['.DS_Store', 'test', 'train', 'val']

# %%
from keras.applications import inception_v3
from keras.layers import Dense,GlobalAveragePooling2D
from sklearn.metrics import confusion_matrix, f1_score
from keras.models import Model

# %%
import matplotlib.pyplot as plt
import numpy as np
import os, shutil
from keras import models
from keras import layers
from sklearn.metrics import confusion_matrix, f1_score
np.random.seed(123)
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

# %%
directory = 'chest_xray/'

# %%
# get all the data in the directory split/test, and reshape them
data_all = ImageDataGenerator(rescale=1./255).flow_from_directory( 
        directory, 
        target_size=(226, 226), 
        batch_size = 4419, 
        seed = 123)
# Out:
# Found 5856 images belonging to 3 classes.

# %%
#split images and labels
images, labels = next(data_all)

# %%
#visualize images
# %matplotlib inline
import matplotlib.pyplot as plt

for i in range(9):
  plt.subplot(330 + 1 + i)
  plt.imshow(images[i])
plt.show()

# %%
#reshape labels
labels = np.reshape(labels[:,0], (4419,1))

# %%
from sklearn.model_selection import train_test_split
X_model, X_test, y_model, y_test = train_test_split(images, labels, test_size=0.20, random_state=123)

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X_model, y_model, test_size=0.20, random_state=123)

# %%
cnn = models.Sequential()
cnn.add(layers.Conv2D(64, (3, 3), activation='relu', input_shape=(226, 226,  3)))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(layers.Conv2D(32, (3, 3), activation='relu'))
cnn.add(layers.MaxPooling2D((2, 2)))
cnn.add(layers.Flatten())
cnn.add(layers.Dense(32, activation='relu'))
cnn.add(layers.Dense(1, activation='sigmoid'))

cnn.compile(loss='binary_crossentropy',
              optimizer="sgd",
              metrics=['acc'])

# %%
cnn1 = cnn.fit(X_train,
                    y_train,
                    epochs=20,
                    batch_size=50,
                    workers=-1,
                    verbose=1,
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/20
# 57/57 [==============================] - 81s 1s/step - loss: 0.3469 - acc: 0.8897 - val_loss: 0.3212 - val_acc: 0.8996
# Epoch 2/20
# 57/57 [==============================] - 82s 1s/step - loss: 0.3462 - acc: 0.8897 - val_loss: 0.3194 - val_acc: 0.8996
# Epoch 3/20
# 57/57 [==============================] - 80s 1s/step - loss: 0.3392 - acc: 0.8897 - val_loss: 0.3167 - val_acc: 0.8996
# Epoch 4/20
# 57/57 [==============================] - 80s 1s/step - loss: 0.3408 - acc: 0.8897 - val_loss: 0.3214 - val_acc: 0.8996
# Epoch 5/20
# 57/57 [==============================] - 80s 1s/step - loss: 0.3379 - acc: 0.8897 - val_loss: 0.3159 - val_acc: 0.8996
# Epoch 6/20
# 57/57 [==============================] - 80s 1s/step - loss: 0.3359 - acc: 0.8897 - val_loss: 0.3166 - val_acc: 0.8996
# Epoch 7/20
# 57/57 [==============================] - 86s 2s/step - loss: 0.3339 - acc: 0.8897 - val_loss: 0.3098 - val_acc: 0.8996
# Epoch 8/20
# 57/57 [==============================] - 81s 1s/step - loss: 0.3316 - acc: 0.8897 - val_loss: 0.3088 - val_acc: 0.8996
# Epoch 9/20
# 57/57 [==============================] - 80s 1s/step - loss: 0.3371 - acc: 0.8897 - val_loss: 0.3145 - val_acc: 0.8996
# Epoch 10/20
# 57/57 [==============================] - 80s 1s/step - loss: 0.3309 - acc: 0.8897 - val_loss: 0.3719 - val_acc: 0.8996
# Epoch 11/20
# 57/57 [==============================] - 81s 1s/step - loss: 0.3326 - acc: 0.8897 - val_loss: 0.3111 - val_acc: 0.8996
# Epoch 12/20
# 57/57 [==============================] - 81s 1s/step - loss: 0.3295 - acc: 0.8897 - val_loss: 0.3082 - val_acc: 0.8996
# Epoch 13/20
# 57/57 [==============================] - 82s 1s/step - loss: 0.3294 - acc: 0.8897 - val_loss: 0.3150 - val_acc: 0.8996
# Epoch 14/20
# 57/57 [==============================] - 83s 1s/step - loss: 0.3285 - acc: 0.8897 - val_loss: 0.3079 - val_acc: 0.8996
# Epoch 15/20
# 57/57 [==============================] - 81s 1s/step - loss: 0.3310 - acc: 0.8897 - val_loss: 0.3836 - val_acc: 0.8996
# Epoch 16/20
# 57/57 [==============================] - 81s 1s/step - loss: 0.3276 - acc: 0.8897 - val_loss: 0.3373 - val_acc: 0.8996
# Epoch 17/20
# 57/57 [==============================] - 81s 1s/step - loss: 0.3243 - acc: 0.8897 - val_loss: 0.3030 - val_acc: 0.8996
# Epoch 18/20
# 57/57 [==============================] - 81s 1s/step - loss: 0.3217 - acc: 0.8897 - val_loss: 0.3151 - val_acc: 0.8996
# Epoch 19/20
# 57/57 [==============================] - 82s 1s/step - loss: 0.3219 - acc: 0.8897 - val_loss: 0.3036 - val_acc: 0.8996
# Epoch 20/20
# 57/57 [==============================] - 82s 1s/step - loss: 0.3226 - acc: 0.8897 - val_loss: 0.3045 - val_acc: 0.8996

# %%
hist_cnn = cnn1.history
loss_values = hist_cnn['loss']
val_loss_values = hist_cnn['val_loss']
acc_values = hist_cnn['acc'] 
val_acc_values = hist_cnn['val_acc']


epochs = range(1, len(loss_values) + 1)

plt.figure(figsize=(15,4))
plt.subplot(121)
plt.plot(epochs, loss_values, 'g.', label='Training loss')
plt.plot(epochs, val_loss_values, 'g', label='Validation loss')

plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

plt.subplot(122)
plt.plot(epochs, acc_values, 'r.', label='Training acc')
plt.plot(epochs, val_acc_values, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
results_train = cnn.evaluate(X_train, y_train)
results_test = cnn.evaluate(X_test, y_test)
print(results_train, results_test)
# Out:
# 89/89 [==============================] - 18s 201ms/step - loss: 0.3208 - acc: 0.8897
# 28/28 [==============================] - 6s 220ms/step - loss: 0.3141 - acc: 0.8959
# [0.3207727372646332, 0.8896746635437012] [0.3141483962535858, 0.8959276080131531]

# %%
imagenet=inception_v3.InceptionV3(weights='imagenet',include_top=False)
imagenet_new=imagenet.output
new_model = models.Sequential()
new_model.add(imagenet)
new_model.add(GlobalAveragePooling2D())
new_model.add(Dense(1024,activation='relu'))
new_model.add(Dense(1024,activation='relu')) #dense layer 2
new_model.add(Dense(512,activation='relu')) #dense layer 3
new_model.add(Dense(1,activation='sigmoid')) #final layer with softmax activation
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 2s 0us/step

# %%
for i,layer in enumerate(imagenet.layers):
  print(i,layer.name, layer.trainable)
# Out:
# 0 input_1 True
# 1 conv2d_2 True
# 2 batch_normalization True
# 3 activation True
# 4 conv2d_3 True
# 5 batch_normalization_1 True
# 6 activation_1 True
# 7 conv2d_4 True
# 8 batch_normalization_2 True
# 9 activation_2 True
# 10 max_pooling2d_2 True
# 11 conv2d_5 True
# 12 batch_normalization_3 True
# 13 activation_3 True
# 14 conv2d_6 True
# 15 batch_normalization_4 True
# 16 activation_4 True
# 17 max_pooling2d_3 True
# 18 conv2d_10 True
# 19 batch_normalization_8 True
# 20 activation_8 True
# 21 conv2d_8 True
# 22 conv2d_11 True
# 23 batch_normalization_6 True
# 24 batch_normalization_9 True
# 25 activation_6 True
# 26 activation_9 True
# 27 average_pooling2d True
# 28 conv2d_7 True
# 29 conv2d_9 True
# 30 conv2d_12 True
# 31 conv2d_13 True
# 32 batch_normalization_5 True
# 33 batch_normalization_7 True
# 34 batch_normalization_10 True
# 35 batch_normalization_11 True
# 36 activation_5 True
# 37 activation_7 True
# 38 activation_10 True
# 39 activation_11 True
# 40 mixed0 True
# 41 conv2d_17 True
# 42 batch_normalization_15 True
# 43 activation_15 True
# 44 conv2d_15 True
# 45 conv2d_18 True
# 46 batch_normalization_13 True
# 47 batch_normalization_16 True
# 48 activation_13 True
# 49 activation_16 True
# 50 average_pooling2d_1 True
# 51 conv2d_14 True
# 52 conv2d_16 True
# 53 conv2d_19 True
# 54 conv2d_20 True
# 55 batch_normalization_12 True
# 56 batch_normalization_14 True
# 57 batch_normalization_17 True
# 58 batch_normalization_18 True
# 59 activation_12 True
# 60 activation_14 True
# 61 activation_17 True
# 62 activation_18 True
# 63 mixed1 True
# 64 conv2d_24 True
# 65 batch_normalization_22 True
# 66 activation_22 True
# 67 conv2d_22 True
# 68 conv2d_25 True
# 69 batch_normalization_20 True
# 70 batch_normalization_23 True
# 71 activation_20 True
# 72 activation_23 True
# 73 average_pooling2d_2 True
# 74 conv2d_21 True
# 75 conv2d_23 True
# 76 conv2d_26 True
# 77 conv2d_27 True
# 78 batch_normalization_19 True
# 79 batch_normalization_21 True
# 80 batch_normalization_24 True
# 81 batch_normalization_25 True
# 82 activation_19 True
# 83 activation_21 True
# 84 activation_24 True
# 85 activation_25 True
# 86 mixed2 True
# 87 conv2d_29 True
# 88 batch_normalization_27 True
# 89 activation_27 True
# 90 conv2d_30 True
# 91 batch_normalization_28 True
# 92 activation_28 True
# 93 conv2d_28 True
# 94 conv2d_31 True
# 95 batch_normalization_26 True
# 96 batch_normalization_29 True
# 97 activation_26 True
# 98 activation_29 True
# 99 max_pooling2d_4 True
# 100 mixed3 True
# 101 conv2d_36 True
# 102 batch_normalization_34 True
# 103 activation_34 True
# 104 conv2d_37 True
# 105 batch_normalization_35 True
# 106 activation_35 True
# 107 conv2d_33 True
# 108 conv2d_38 True
# 109 batch_normalization_31 True
# 110 batch_normalization_36 True
# 111 activation_31 True
# 112 activation_36 True
# 113 conv2d_34 True
# 114 conv2d_39 True
# 115 batch_normalization_32 True
# 116 batch_normalization_37 True
# 117 activation_32 True
# 118 activation_37 True
# 119 average_pooling2d_3 True
# 120 conv2d_32 True
# 121 conv2d_35 True
# 122 conv2d_40 True
# 123 conv2d_41 True
# 124 batch_normalization_30 True
# 125 batch_normalization_33 True
# 126 batch_normalization_38 True
# 127 batch_normalization_39 True
# 128 activation_30 True
# 129 activation_33 True
# 130 activation_38 True
# 131 activation_39 True
# 132 mixed4 True
# 133 conv2d_46 True
# 134 batch_normalization_44 True
# 135 activation_44 True
# 136 conv2d_47 True
# 137 batch_normalization_45 True
# 138 activation_45 True
# 139 conv2d_43 True
# 140 conv2d_48 True
# 141 batch_normalization_41 True
# 142 batch_normalization_46 True
# 143 activation_41 True
# 144 activation_46 True
# 145 conv2d_44 True
# 146 conv2d_49 True
# 147 batch_normalization_42 True
# 148 batch_normalization_47 True
# 149 activation_42 True
# 150 activation_47 True
# 151 average_pooling2d_4 True
# 152 conv2d_42 True
# 153 conv2d_45 True
# 154 conv2d_50 True
# 155 conv2d_51 True
# 156 batch_normalization_40 True
# 157 batch_normalization_43 True
# 158 batch_normalization_48 True
# 159 batch_normalization_49 True
# 160 activation_40 True
# 161 activation_43 True
# 162 activation_48 True
# 163 activation_49 True
# 164 mixed5 True
# 165 conv2d_56 True
# 166 batch_normalization_54 True
# 167 activation_54 True
# 168 conv2d_57 True
# 169 batch_normalization_55 True
# 170 activation_55 True
# 171 conv2d_53 True
# 172 conv2d_58 True
# 173 batch_normalization_51 True
# 174 batch_normalization_56 True
# 175 activation_51 True
# 176 activation_56 True
# 177 conv2d_54 True
# 178 conv2d_59 True
# 179 batch_normalization_52 True
# 180 batch_normalization_57 True
# 181 activation_52 True
# 182 activation_57 True
# 183 average_pooling2d_5 True
# 184 conv2d_52 True
# 185 conv2d_55 True
# 186 conv2d_60 True
# 187 conv2d_61 True
# 188 batch_normalization_50 True
# 189 batch_normalization_53 True
# 190 batch_normalization_58 True
# 191 batch_normalization_59 True
# 192 activation_50 True
# 193 activation_53 True
# 194 activation_58 True
# 195 activation_59 True
# 196 mixed6 True
# 197 conv2d_66 True
# 198 batch_normalization_64 True
# 199 activation_64 True
# 200 conv2d_67 True
# 201 batch_normalization_65 True
# 202 activation_65 True
# 203 conv2d_63 True
# 204 conv2d_68 True
# 205 batch_normalization_61 True
# 206 batch_normalization_66 True
# 207 activation_61 True
# 208 activation_66 True
# 209 conv2d_64 True
# 210 conv2d_69 True
# 211 batch_normalization_62 True
# 212 batch_normalization_67 True
# 213 activation_62 True
# 214 activation_67 True
# 215 average_pooling2d_6 True
# 216 conv2d_62 True
# 217 conv2d_65 True
# 218 conv2d_70 True
# 219 conv2d_71 True
# 220 batch_normalization_60 True
# 221 batch_normalization_63 True
# 222 batch_normalization_68 True
# 223 batch_normalization_69 True
# 224 activation_60 True
# 225 activation_63 True
# 226 activation_68 True
# 227 activation_69 True
# 228 mixed7 True
# 229 conv2d_74 True
# 230 batch_normalization_72 True
# 231 activation_72 True
# 232 conv2d_75 True
# 233 batch_normalization_73 True
# 234 activation_73 True
# 235 conv2d_72 True
# 236 conv2d_76 True
# 237 batch_normalization_70 True
# 238 batch_normalization_74 True
# 239 activation_70 True
# 240 activation_74 True
# 241 conv2d_73 True
# 242 conv2d_77 True
# 243 batch_normalization_71 True
# 244 batch_normalization_75 True
# 245 activation_71 True
# 246 activation_75 True
# 247 max_pooling2d_5 True
# 248 mixed8 True
# 249 conv2d_82 True
# 250 batch_normalization_80 True
# 251 activation_80 True
# 252 conv2d_79 True
# 253 conv2d_83 True
# 254 batch_normalization_77 True
# 255 batch_normalization_81 True
# 256 activation_77 True
# 257 activation_81 True
# 258 conv2d_80 True
# 259 conv2d_81 True
# 260 conv2d_84 True
# 261 conv2d_85 True
# 262 average_pooling2d_7 True
# 263 conv2d_78 True
# 264 batch_normalization_78 True
# 265 batch_normalization_79 True
# 266 batch_normalization_82 True
# 267 batch_normalization_83 True
# 268 conv2d_86 True
# 269 batch_normalization_76 True
# 270 activation_78 True
# 271 activation_79 True
# 272 activation_82 True
# 273 activation_83 True
# 274 batch_normalization_84 True
# 275 activation_76 True
# 276 mixed9_0 True
# 277 concatenate True
# 278 activation_84 True
# 279 mixed9 True
# 280 conv2d_91 True
# 281 batch_normalization_89 True
# 282 activation_89 True
# 283 conv2d_88 True
# 284 conv2d_92 True
# 285 batch_normalization_86 True
# 286 batch_normalization_90 True
# 287 activation_86 True
# 288 activation_90 True
# 289 conv2d_89 True
# 290 conv2d_90 True
# 291 conv2d_93 True
# 292 conv2d_94 True
# 293 average_pooling2d_8 True
# 294 conv2d_87 True
# 295 batch_normalization_87 True
# 296 batch_normalization_88 True
# 297 batch_normalization_91 True
# 298 batch_normalization_92 True
# 299 conv2d_95 True
# 300 batch_normalization_85 True
# 301 activation_87 True
# 302 activation_88 True
# 303 activation_91 True
# 304 activation_92 True
# 305 batch_normalization_93 True
# 306 activation_85 True
# 307 mixed9_1 True
# 308 concatenate_1 True
# 309 activation_93 True
# 310 mixed10 True

# %%
for i,layer in enumerate(new_model.layers):
  print(i,layer.name, layer.trainable)
# Out:
# 0 inception_v3 True
# 1 global_average_pooling2d True
# 2 dense_2 True
# 3 dense_3 True
# 4 dense_4 True
# 5 dense_5 True

# %%
for layer in new_model.layers[:1]:
    layer.trainable=False

# %%
for i,layer in enumerate(new_model.layers):
  print(i,layer.name, layer.trainable)
# Out:
# 0 inception_v3 False
# 1 global_average_pooling2d True
# 2 dense_2 True
# 3 dense_3 True
# 4 dense_4 True
# 5 dense_5 True

# %%
new_model.compile(optimizer='Adam',loss='binary_crossentropy',metrics=['accuracy'])

# step_size_train=train_generator.n//train_generator.batch_size
new_model.fit(X_train,
          y_train,
          epochs=5,
          batch_size=50,
          validation_data=(X_val, y_val))
# Out:
# Epoch 1/5
# 57/57 [==============================] - 98s 2s/step - loss: 0.4273 - accuracy: 0.8861 - val_loss: 0.3188 - val_accuracy: 0.8996
# Epoch 2/5
# 57/57 [==============================] - 93s 2s/step - loss: 0.3496 - accuracy: 0.8897 - val_loss: 0.3119 - val_accuracy: 0.8996
# Epoch 3/5
# 57/57 [==============================] - 92s 2s/step - loss: 0.3327 - accuracy: 0.8897 - val_loss: 0.3164 - val_accuracy: 0.8996
# Epoch 4/5
# 57/57 [==============================] - 94s 2s/step - loss: 0.3342 - accuracy: 0.8897 - val_loss: 0.3171 - val_accuracy: 0.8996
# Epoch 5/5
# 57/57 [==============================] - 91s 2s/step - loss: 0.3299 - accuracy: 0.8897 - val_loss: 0.3163 - val_accuracy: 0.8996

# %%
new_model.evaluate(X_test, y_test)
# Out:
# 28/28 [==============================] - 23s 814ms/step - loss: 0.3287 - accuracy: 0.8959
# [0.3287322521209717, 0.8959276080131531]

# %%
predictions_transfer = new_model.predict(X_test)
predictions_transfer = np.around(predictions_transfer)

# %%
f1_score(y_test, predictions_transfer)
# Out:
# 0.0

# %%
import itertools

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
plt.figure()
plot_confusion_matrix(confusion_matrix(y_test, predictions_transfer), classes=['pneumonia', 'not pneumonia, dog'], normalize=False,
                      title='Confusion matrix - ImagenetV3')
# Out:
# Confusion matrix, without normalization
# [[792   0]
#  [ 92   0]]

# %%
#def predictoneimage_cnn(model, path):
#    img = load_img(path, target_size=(224, 224))
#    plt.imshow(img)
#    img = img_to_array(img)
#    img = img/255
#    img = np.expand_dims(img, axis=0)
#    predict = model.predict(img)
#    return predict

# %%
#predictoneimage_cnn(new_model, 'data/hotdog1.jpg')
